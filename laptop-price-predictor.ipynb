# %%
# importing libraries
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Datasets/laptops.csv')

# %%
df.head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# ...

# %%
df.tail()
# Out:
#                                                  Laptop       Status  Brand  \
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished  Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished  Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished  Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished  Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished  Razer
#
#       Model                CPU  RAM  Storage Storage type       GPU  Screen  \
# 2155  Blade      Intel Core i7   16     1000          SSD  RTX 3060    17.3
# 2156  Blade      Intel Core i7   16     1000          SSD  RTX 3070    17.3
# 2157  Blade      Intel Core i7   32     1000          SSD  RTX 3080    17.3
# 2158   Book  Intel Evo Core i7   16     1000          SSD       NaN    13.4
# 2159   Book  Intel Evo Core i7   16      256          SSD       NaN    13.4
#
#      Touch  Final Price
# 2155    No      2699.99
# ...

# %%
df.shape
# Out:
# (2160, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laptop        2160 non-null   object
#  1   Status        2160 non-null   object
#  2   Brand         2160 non-null   object
#  3   Model         2160 non-null   object
#  4   CPU           2160 non-null   object
#  5   RAM           2160 non-null   int64
#  6   Storage       2160 non-null   int64
#  7   Storage type  2118 non-null   object
#  8   GPU           789 non-null    object
#  9   Screen        2156 non-null   float64
#  10  Touch         2160 non-null   object
#  11  Final Price   2160 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 202.6+ KB

# %%
df.isnull().sum()
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             4
# Touch              0
# Final Price        0
# dtype: int64

# %%
## checking duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Status'].unique()
# Out:
# array(['New', 'Refurbished'], dtype=object)

# %%
df['Status'].value_counts()
# Out:
# Status
# New            1498
# Refurbished     662
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Laptop', 'Status', 'Brand', 'Model', 'CPU', 'RAM', 'Storage',
#        'Storage type', 'GPU', 'Screen', 'Touch', 'Final Price'],
#       dtype='object')

# %%
for col in df.columns:
    if df[col].dtype=="O":
        print("Column Name -> ",col)
        print()
        print(df[col].unique())
        print()
        print(df[col].value_counts())
        print("-"*40)
        print()
# Out:
# Column Name ->  Laptop
#
# ['ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core i5-1235U/8GB/512GB SSD/15.6"'
#  'Alurin Go Start Intel Celeron N4020/8GB/256GB SSD/15.6"'
#  'ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core i3-1215U/8GB/256GB SSD/15.6"'
#  ...
#  'Razer Blade 17 FHD 360Hz Intel Core i7-11800H/32GB/1TB SSD/RTX 3080/17.3"'
#  'Razer Book 13 Intel Evo Core i7-1165G7/16GB/1TB SSD/13.4" Táctil'
#  'Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/256GB SSD/13.4" Táctil']
#
# Laptop
# PcCom Revolt One 3070 Intel Core i7-11800H/16GB/1TB SSD/RTX 3070/17.3"                    1
# PcCom Revolt One 3060 Intel Core i7-11800H/16GB/1TB SSD/RTX 3060/15.6"                    1
# PcCom Revolt One 3050 Intel Core i5-11400H/16GB/512GB SSD/RTX 3050/15.6"                  1
# PcCom Revolt 4060 Intel Core i7-13700H/32GB/500GB SSD/RTX 4060/15.6” + Windows 11 Home    1
# PcCom Revolt 4060 Intel Core i7-13700H/32GB/500GB SSD/RTX 4060/15.6"                      1
# ...

# %%
df['Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand'>

# %%
df['Brand'].unique()
# Out:
# array(['Asus', 'Alurin', 'MSI', 'HP', 'Lenovo', 'Medion', 'Acer', 'Apple',
#        'Razer', 'Gigabyte', 'Dell', 'LG', 'Samsung', 'PcCom', 'Microsoft',
#        'Primux', 'Prixton', 'Dynabook Toshiba', 'Thomson', 'Denver',
#        'Deep Gaming', 'Vant', 'Innjoo', 'Jetwing', 'Millenium', 'Realme',
#        'Toshiba'], dtype=object)

# %%
# df.drop(columns=['Vant', 'Innjoo', 'Jetwing', 'Millenium', 'Realme','Toshiba','Deep Gaming'])

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x=df['Brand'],y=df['Final Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.columns
# Out:
# Index(['Laptop', 'Status', 'Brand', 'Model', 'CPU', 'RAM', 'Storage',
#        'Storage type', 'GPU', 'Screen', 'Touch', 'Final Price'],
#       dtype='object')

# %%
df.head(3)
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
#
#         Model            CPU  RAM  Storage Storage type  GPU  Screen Touch  \
# 0  ExpertBook  Intel Core i5    8      512          SSD  NaN    15.6    No
# 1          Go  Intel Celeron    8      256          SSD  NaN    15.6    No
# 2  ExpertBook  Intel Core i3    8      256          SSD  NaN    15.6    No
#
#    Final Price
# 0       1009.0
# 1        299.0
# 2        789.0

# %%
df['Model'].value_counts()
# Out:
# Model
# 15S         115
# IdeaPad     104
# ROG         101
# VivoBook     99
# ThinkPad     99
#            ...
# A7            1
# V330          1
# Delta         1
# GL65          1
# GL75          1
# Name: count, Length: 121, dtype: int64

# %%
sns.scatterplot(x=df['Screen'],y=df['Final Price'])
# Out:
# <Axes: xlabel='Screen', ylabel='Final Price'>

# %%
sns.barplot(x=df['Touch'], y=df['Final Price'])
# Out:
# <Axes: xlabel='Touch', ylabel='Final Price'>

# %%
df.drop("GPU",axis=1,inplace=True)

# %%
df.shape
# Out:
# (2160, 11)

# %%
df.isnull().sum()
# Out:
# Laptop           0
# Status           0
# Brand            0
# Model            0
# CPU              0
# RAM              0
# Storage          0
# Storage type    42
# Screen           4
# Touch            0
# Final Price      0
# dtype: int64

# %%
df['Storage type'].value_counts()
# Out:
# Storage type
# SSD     2062
# eMMC      56
# Name: count, dtype: int64

# %%
df=df[df['Storage type']!="eMMC"]

# %%
df
# Out:
#                                                  Laptop       Status   Brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
# ...

# %%
df['Storage type'].unique()
# Out:
# array(['SSD', nan], dtype=object)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index                                             Laptop       Status  \
# 0         0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New
# 1         1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New
# 2         2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New
# 3         3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New
# 4         4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New
# ...     ...                                                ...          ...
# 2099   2155  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished
# 2100   2156  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished
# 2101   2157  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished
# 2102   2158  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished
# 2103   2159  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished
#
# ...

# %%
df.isnull().sum()
# Out:
# index            0
# Laptop           0
# Status           0
# Brand            0
# Model            0
# CPU              0
# RAM              0
# Storage          0
# Storage type    42
# Screen           4
# Touch            0
# Final Price      0
# dtype: int64

# %%
df.fillna("SSD",inplace=True)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_18612\1644170632.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'SSD' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("SSD",inplace=True)

# %%
df.isnull().sum()
# Out:
# index           0
# Laptop          0
# Status          0
# Brand           0
# Model           0
# CPU             0
# RAM             0
# Storage         0
# Storage type    0
# Screen          0
# Touch           0
# Final Price     0
# dtype: int64

# %%
df['Storage type'].unique()
# Out:
# array(['SSD'], dtype=object)

# %%
df.columns
# Out:
# Index(['index', 'Laptop', 'Status', 'Brand', 'Model', 'CPU', 'RAM', 'Storage',
#        'Storage type', 'Screen', 'Touch', 'Final Price'],
#       dtype='object')

# %%
df.drop("index",axis=1,inplace=True)

# %%
df
# Out:
#                                                  Laptop       Status   Brand  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New    Asus
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New  Alurin
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New    Asus
# 3     MSI Katana GF66 12UC-082XES Intel Core i7-1270...          New     MSI
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New      HP
# ...                                                 ...          ...     ...
# 2099  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2100  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2101  Razer Blade 17 FHD 360Hz Intel Core i7-11800H/...  Refurbished   Razer
# 2102  Razer Book 13 Intel Evo Core i7-1165G7/16GB/1T...  Refurbished   Razer
# 2103  Razer Book FHD+ Intel Evo Core i7-1165G7/16GB/...  Refurbished   Razer
#
# ...

# %%
df.columns
# Out:
# Index(['Laptop', 'Status', 'Brand', 'Model', 'CPU', 'RAM', 'Storage',
#        'Storage type', 'Screen', 'Touch', 'Final Price'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Laptop', 'Status', 'Brand', 'Model', 'CPU', 'RAM', 'Storage',
#        'Storage type', 'Screen', 'Touch', 'Final Price'],
#       dtype='object')

# %%
df.rename(columns={'Storage': 'SSD Size'},inplace=True)

# %%
df.drop(columns=["Laptop","Storage type"],inplace=True)

# %%
df.head(3)
# Out:
#   Status   Brand       Model            CPU  RAM  SSD Size Screen Touch  \
# 0    New    Asus  ExpertBook  Intel Core i5    8       512   15.6    No
# 1    New  Alurin          Go  Intel Celeron    8       256   15.6    No
# 2    New    Asus  ExpertBook  Intel Core i3    8       256   15.6    No
#
#    Final Price
# 0       1009.0
# 1        299.0
# 2        789.0

# %%
df['Status'].value_counts()
# Out:
# Status
# New            1449
# Refurbished     655
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Status', 'Brand', 'Model', 'CPU', 'RAM', 'SSD Size', 'Screen', 'Touch',
#        'Final Price'],
#       dtype='object')

# %%
df['Touch'].value_counts()
# Out:
# Touch
# No     1891
# Yes     213
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Touch'],y=df['Final Price'])
# Out:
# <Axes: xlabel='Touch', ylabel='Final Price'>

# %%
df.shape
# Out:
# (2104, 9)

# %%
sns.displot(df['Brand'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(df['CPU'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['CPU'].value_counts()
# Out:
# CPU
# Intel Core i7            710
# Intel Core i5            534
# AMD Ryzen 7              156
# Intel Core i3            129
# AMD Ryzen 5              127
# Intel Core i9             94
# Intel Evo Core i7         82
# Intel Celeron             52
# AMD Ryzen 3               44
# AMD Ryzen 9               44
# Intel Evo Core i5         30
# Apple M2                  28
# Apple M2 Pro              13
# AMD 3020e                 12
# Apple M1                  10
# Intel Pentium              9
# AMD Athlon                 8
# Apple M1 Pro               7
# Intel Core M3              4
# Microsoft SQ1              3
# AMD 3015e                  2
# AMD Radeon 9               2
# Qualcomm Snapdragon 8      2
# AMD Radeon 5               1
# Intel Evo Core i9          1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Status   Brand       Model            CPU  RAM  SSD Size Screen Touch  \
# 0    New    Asus  ExpertBook  Intel Core i5    8       512   15.6    No
# 1    New  Alurin          Go  Intel Celeron    8       256   15.6    No
# 2    New    Asus  ExpertBook  Intel Core i3    8       256   15.6    No
# 3    New     MSI      Katana  Intel Core i7   16      1000   15.6    No
# 4    New      HP         15S  Intel Core i5   16       512   15.6    No
#
#    Final Price
# 0      1009.00
# 1       299.00
# 2       789.00
# 3      1199.00
# 4       669.01

# %%
df.tail()
# Out:
#            Status  Brand  Model                CPU  RAM  SSD Size Screen  \
# 2099  Refurbished  Razer  Blade      Intel Core i7   16      1000   17.3
# 2100  Refurbished  Razer  Blade      Intel Core i7   16      1000   17.3
# 2101  Refurbished  Razer  Blade      Intel Core i7   32      1000   17.3
# 2102  Refurbished  Razer   Book  Intel Evo Core i7   16      1000   13.4
# 2103  Refurbished  Razer   Book  Intel Evo Core i7   16       256   13.4
#
#      Touch  Final Price
# 2099    No      2699.99
# 2100    No      2899.99
# 2101    No      3399.99
# 2102   Yes      1899.99
# 2103   Yes      1699.99

# %%
df.shape
# Out:
# (2104, 9)

# %%
df['CPU'].unique()
# Out:
# array(['Intel Core i5', 'Intel Celeron', 'Intel Core i3', 'Intel Core i7',
#        'AMD Ryzen 5', 'AMD Ryzen 7', 'AMD Ryzen 3', 'Apple M1',
#        'AMD Athlon', 'Apple M2', 'AMD Ryzen 9', 'Intel Core i9',
#        'AMD 3020e', 'Intel Evo Core i7', 'Intel Evo Core i5',
#        'Apple M2 Pro', 'Intel Pentium', 'AMD Radeon 5',
#        'Intel Evo Core i9', 'AMD 3015e', 'Apple M1 Pro', 'Intel Core M3',
#        'AMD Radeon 9', 'Qualcomm Snapdragon 8', 'Microsoft SQ1'],
#       dtype=object)

# %%
cpu_counts = df['CPU'].value_counts().reset_index()

# %%
cpu_counts
# Out:
#                       CPU  count
# 0           Intel Core i7    710
# 1           Intel Core i5    534
# 2             AMD Ryzen 7    156
# 3           Intel Core i3    129
# 4             AMD Ryzen 5    127
# 5           Intel Core i9     94
# 6       Intel Evo Core i7     82
# 7           Intel Celeron     52
# 8             AMD Ryzen 3     44
# 9             AMD Ryzen 9     44
# 10      Intel Evo Core i5     30
# 11               Apple M2     28
# 12           Apple M2 Pro     13
# 13              AMD 3020e     12
# 14               Apple M1     10
# 15          Intel Pentium      9
# 16             AMD Athlon      8
# 17           Apple M1 Pro      7
# 18          Intel Core M3      4
# 19          Microsoft SQ1      3
# 20              AMD 3015e      2
# 21           AMD Radeon 9      2
# 22  Qualcomm Snapdragon 8      2
# 23           AMD Radeon 5      1
# 24      Intel Evo Core i9      1

# %%
cpu_counts.columns = ['CPU', 'cpu_count']

# %%
cpu_counts
# Out:
#                       CPU  cpu_count
# 0           Intel Core i7        710
# 1           Intel Core i5        534
# 2             AMD Ryzen 7        156
# 3           Intel Core i3        129
# 4             AMD Ryzen 5        127
# 5           Intel Core i9         94
# 6       Intel Evo Core i7         82
# 7           Intel Celeron         52
# 8             AMD Ryzen 3         44
# 9             AMD Ryzen 9         44
# 10      Intel Evo Core i5         30
# 11               Apple M2         28
# 12           Apple M2 Pro         13
# 13              AMD 3020e         12
# 14               Apple M1         10
# 15          Intel Pentium          9
# 16             AMD Athlon          8
# 17           Apple M1 Pro          7
# 18          Intel Core M3          4
# 19          Microsoft SQ1          3
# 20              AMD 3015e          2
# 21           AMD Radeon 9          2
# 22  Qualcomm Snapdragon 8          2
# 23           AMD Radeon 5          1
# ...

# %%
cpu_counts.columns
# Out:
# Index(['CPU', 'cpu_count'], dtype='object')

# %%
type(cpu_counts)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   Status   Brand       Model            CPU  RAM  SSD Size Screen Touch  \
# 0    New    Asus  ExpertBook  Intel Core i5    8       512   15.6    No
# 1    New  Alurin          Go  Intel Celeron    8       256   15.6    No
# 2    New    Asus  ExpertBook  Intel Core i3    8       256   15.6    No
# 3    New     MSI      Katana  Intel Core i7   16      1000   15.6    No
# 4    New      HP         15S  Intel Core i5   16       512   15.6    No
#
#    Final Price
# 0      1009.00
# 1       299.00
# 2       789.00
# 3      1199.00
# 4       669.01

# %%
df = df.merge(cpu_counts, on='CPU', how='right')

# %%
df.head()
# Out:
#   Status Brand      Model            CPU  RAM  SSD Size Screen Touch  \
# 0    New   MSI     Katana  Intel Core i7   16      1000   15.6    No
# 1    New   MSI  Crosshair  Intel Core i7   32      1000   17.3    No
# 2    New  Asus   VivoBook  Intel Core i7    8       512   15.6    No
# 3    New    HP     Victus  Intel Core i7   16       512   16.1    No
# 4    New   MSI       Thin  Intel Core i7   16      1000   15.6    No
#
#    Final Price  cpu_count
# 0      1199.00        710
# 1      1699.00        710
# 2       809.01        710
# 3      1149.00        710
# 4      1399.00        710

# %%
df['cpu_count'].unique()
# Out:
# array([710, 534, 156, 129, 127,  94,  82,  52,  44,  30,  28,  13,  12,
#         10,   9,   8,   7,   4,   3,   2,   1])

# %%
df.shape
# Out:
# (2104, 10)

# %%
# Keeping only rows in data frame where CPU count >= 10. Only keeping CPU's which are 10 or more than 10 times in data
df=df[df['cpu_count']>10]

# %%
df.head()
# Out:
#   Status Brand      Model            CPU  RAM  SSD Size Screen Touch  \
# 0    New   MSI     Katana  Intel Core i7   16      1000   15.6    No
# 1    New   MSI  Crosshair  Intel Core i7   32      1000   17.3    No
# 2    New  Asus   VivoBook  Intel Core i7    8       512   15.6    No
# 3    New    HP     Victus  Intel Core i7   16       512   16.1    No
# 4    New   MSI       Thin  Intel Core i7   16      1000   15.6    No
#
#    Final Price  cpu_count
# 0      1199.00        710
# 1      1699.00        710
# 2       809.01        710
# 3      1149.00        710
# 4      1399.00        710

# %%
df.shape
# Out:
# (2055, 10)

# %%
brand_counts=df['Brand'].value_counts().reset_index()

# %%
brand_counts.columns=['Brand','brand_count']

# %%
type(brand_counts)
# Out:
# pandas.core.frame.DataFrame

# %%
brand_counts
# Out:
#                Brand  brand_count
# 0               Asus          391
# 1             Lenovo          355
# 2                 HP          349
# 3                MSI          308
# 4               Acer          128
# 5              Apple           96
# 6               Dell           84
# 7          Microsoft           71
# 8           Gigabyte           48
# 9              Razer           37
# 10                LG           32
# 11            Medion           31
# 12             PcCom           24
# 13            Alurin           24
# 14           Samsung           19
# 15  Dynabook Toshiba           19
# 16              Vant           11
# 17       Deep Gaming            8
# 18            Primux            8
# 19            Innjoo            3
# 20         Millenium            2
# 21           Prixton            2
# 22           Thomson            1
# 23           Jetwing            1
# 24            Realme            1
# 25           Toshiba            1
# ...

# %%
df=df.merge(brand_counts)

# %%
df.head()
# Out:
#   Status Brand      Model            CPU  RAM  SSD Size Screen Touch  \
# 0    New   MSI     Katana  Intel Core i7   16      1000   15.6    No
# 1    New   MSI  Crosshair  Intel Core i7   32      1000   17.3    No
# 2    New  Asus   VivoBook  Intel Core i7    8       512   15.6    No
# 3    New    HP     Victus  Intel Core i7   16       512   16.1    No
# 4    New   MSI       Thin  Intel Core i7   16      1000   15.6    No
#
#    Final Price  cpu_count  brand_count
# 0      1199.00        710          308
# 1      1699.00        710          308
# 2       809.01        710          391
# 3      1149.00        710          349
# 4      1399.00        710          308

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Asus                391
# Lenovo              355
# HP                  349
# MSI                 308
# Acer                128
# Apple                96
# Dell                 84
# Microsoft            71
# Gigabyte             48
# Razer                37
# LG                   32
# Medion               31
# PcCom                24
# Alurin               24
# Samsung              19
# Dynabook Toshiba     19
# Vant                 11
# Deep Gaming           8
# Primux                8
# Innjoo                3
# Millenium             2
# Prixton               2
# Thomson               1
# Jetwing               1
# Realme                1
# Toshiba               1
# Denver                1
# Name: count, dtype: int64

# %%
# Keeping only rows in data frame where Brand count >= 30. Only keeping Brand's which are 30 or more times in data
df=df[df['brand_count']>=30]

# %%
df.shape
# Out:
# (1930, 11)

# %%
df
# Out:
#            Status   Brand      Model            CPU  RAM  SSD Size Screen  \
# 0             New     MSI     Katana  Intel Core i7   16      1000   15.6
# 1             New     MSI  Crosshair  Intel Core i7   32      1000   17.3
# 2             New    Asus   VivoBook  Intel Core i7    8       512   15.6
# 3             New      HP     Victus  Intel Core i7   16       512   16.1
# 4             New     MSI       Thin  Intel Core i7   16      1000   15.6
# ...           ...     ...        ...            ...  ...       ...    ...
# 2050          New      HP        15S      AMD 3020e    4       256   15.6
# 2051          New      HP        15S      AMD 3020e    4       128   15.6
# 2052          New  Lenovo    IdeaPad      AMD 3020e    4       256   14.0
# 2053  Refurbished  Lenovo    IdeaPad      AMD 3020e    8       256   15.6
# 2054  Refurbished  Lenovo        V15      AMD 3020e    8       256   15.6
#
#      Touch  Final Price  cpu_count  brand_count
# ...

# %%
df
# Out:
#            Status   Brand      Model            CPU  RAM  SSD Size Screen  \
# 0             New     MSI     Katana  Intel Core i7   16      1000   15.6
# 1             New     MSI  Crosshair  Intel Core i7   32      1000   17.3
# 2             New    Asus   VivoBook  Intel Core i7    8       512   15.6
# 3             New      HP     Victus  Intel Core i7   16       512   16.1
# 4             New     MSI       Thin  Intel Core i7   16      1000   15.6
# ...           ...     ...        ...            ...  ...       ...    ...
# 2050          New      HP        15S      AMD 3020e    4       256   15.6
# 2051          New      HP        15S      AMD 3020e    4       128   15.6
# 2052          New  Lenovo    IdeaPad      AMD 3020e    4       256   14.0
# 2053  Refurbished  Lenovo    IdeaPad      AMD 3020e    8       256   15.6
# 2054  Refurbished  Lenovo        V15      AMD 3020e    8       256   15.6
#
#      Touch  Final Price  cpu_count  brand_count
# ...

# %%
df['CPU'].value_counts()
# Out:
# CPU
# Intel Core i7        663
# Intel Core i5        498
# AMD Ryzen 7          156
# AMD Ryzen 5          122
# Intel Core i3        118
# Intel Core i9         94
# Intel Evo Core i7     73
# AMD Ryzen 9           44
# AMD Ryzen 3           43
# Intel Celeron         39
# Apple M2              28
# Intel Evo Core i5     27
# Apple M2 Pro          13
# AMD 3020e             12
# Name: count, dtype: int64

# %%
df['RAM'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='RAM'>

# %%
sns.barplot(x=df['RAM'],y=df['Final Price'])
# plt.xticks(rotation='vertical')
plt.show()

# %%
df.sample()
# Out:
#            Status Brand Model          CPU  RAM  SSD Size Screen Touch  \
# 1960  Refurbished  Asus   ROG  AMD Ryzen 9   32      1000   15.6    No
#
#       Final Price  cpu_count  brand_count
# 1960      1888.94         44          391

# %%
df[df['Brand']=="HP"]
# Out:
#      Status Brand   Model            CPU  RAM  SSD Size Screen Touch  \
# 3       New    HP  Victus  Intel Core i7   16       512   16.1    No
# 10      New    HP     15S  Intel Core i7   16       512   15.6    No
# 11      New    HP    Omen  Intel Core i7   32      1000   16.1    No
# 13      New    HP  Victus  Intel Core i7   16       512   16.1    No
# 14      New    HP     15S  Intel Core i7   16       512   15.6    No
# ...     ...   ...     ...            ...  ...       ...    ...   ...
# 2047    New    HP     15S      AMD 3020e    8       256   15.6    No
# 2048    New    HP     15S      AMD 3020e    8       256   15.6    No
# 2049    New    HP     15S      AMD 3020e    4       128   15.6    No
# 2050    New    HP     15S      AMD 3020e    4       256   15.6    No
# 2051    New    HP     15S      AMD 3020e    4       128   15.6    No
#
#       Final Price  cpu_count  brand_count
# 3         1149.00        710          349
# 10         789.00        710          349
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1930 entries, 0 to 2054
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Status       1930 non-null   object
#  1   Brand        1930 non-null   object
#  2   Model        1930 non-null   object
#  3   CPU          1930 non-null   object
#  4   RAM          1930 non-null   int64
#  5   SSD Size     1930 non-null   int64
#  6   Screen       1930 non-null   object
#  7   Touch        1930 non-null   object
#  8   Final Price  1930 non-null   float64
#  9   cpu_count    1930 non-null   int64
#  10  brand_count  1930 non-null   int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 180.9+ KB

# %%
df['Screen'].value_counts()
# Out:
# Screen
# 15.6    919
# 14.0    334
# 16.0    167
# 17.3    153
# 13.3    106
# 16.1     48
# 17.0     33
# 13.0     23
# 15.0     21
# 13.4     19
# 13.5     18
# 12.3     13
# 13.6     11
# 14.2      9
# 15.3      8
# 11.6      7
# 16.2      7
# 14.4      6
# 15.4      5
# 10.5      5
# SSD       4
# 12.4      4
# 14.5      3
# 18.0      3
# 13.9      2
# 12.0      1
# 12.5      1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1930, 11)

# %%
# removing the rows where value in "SSD" in Screen column
df=df[df['Screen']!="SSD"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1926 entries, 0 to 2054
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Status       1926 non-null   object
#  1   Brand        1926 non-null   object
#  2   Model        1926 non-null   object
#  3   CPU          1926 non-null   object
#  4   RAM          1926 non-null   int64
#  5   SSD Size     1926 non-null   int64
#  6   Screen       1926 non-null   object
#  7   Touch        1926 non-null   object
#  8   Final Price  1926 non-null   float64
#  9   cpu_count    1926 non-null   int64
#  10  brand_count  1926 non-null   int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 180.6+ KB

# %%
df['Screen'].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# Status          object
# Brand           object
# Model           object
# CPU             object
# RAM              int64
# SSD Size         int64
# Screen          object
# Touch           object
# Final Price    float64
# cpu_count        int64
# brand_count      int64
# dtype: object

# %%
df.select_dtypes('int')
# Out:
#       RAM  SSD Size  cpu_count  brand_count
# 0      16      1000        710          308
# 1      32      1000        710          308
# 2       8       512        710          391
# 3      16       512        710          349
# 4      16      1000        710          308
# ...   ...       ...        ...          ...
# 2050    4       256         12          349
# 2051    4       128         12          349
# 2052    4       256         12          355
# 2053    8       256         12          355
# 2054    8       256         12          355
#
# [1926 rows x 4 columns]

# %%
df.Screen=df.Screen.astype('float')
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_18612\1969563138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Screen=df.Screen.astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1926 entries, 0 to 2054
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Status       1926 non-null   object
#  1   Brand        1926 non-null   object
#  2   Model        1926 non-null   object
#  3   CPU          1926 non-null   object
#  4   RAM          1926 non-null   int64
#  5   SSD Size     1926 non-null   int64
#  6   Screen       1926 non-null   float64
#  7   Touch        1926 non-null   object
#  8   Final Price  1926 non-null   float64
#  9   cpu_count    1926 non-null   int64
#  10  brand_count  1926 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 180.6+ KB

# %%
df.describe()
# Out:
#                RAM     SSD Size       Screen  Final Price    cpu_count  \
# count  1926.000000  1926.000000  1926.000000  1926.000000  1926.000000
# mean     15.781931   619.613707    15.242004  1351.282721   421.712357
# std       9.832372   356.191643     1.161381   915.790309   271.376892
# min       4.000000    32.000000    10.500000   210.140000    12.000000
# 25%       8.000000   512.000000    14.000000   699.000000   127.000000
# 50%      16.000000   512.000000    15.600000  1062.170000   534.000000
# 75%      16.000000  1000.000000    15.600000  1749.615000   710.000000
# max     128.000000  4000.000000    18.000000  7150.470000   710.000000
#
#        brand_count
# count  1926.000000
# mean    279.199896
# std     124.569714
# min      31.000000
# 25%     128.000000
# 50%     349.000000
# 75%     355.000000
# max     391.000000

# %%
df.drop(columns=['cpu_count','brand_count'],inplace=True)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_18612\595154615.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['cpu_count','brand_count'],inplace=True)

# %%
df.head()
# Out:
#   Status Brand      Model            CPU  RAM  SSD Size  Screen Touch  \
# 0    New   MSI     Katana  Intel Core i7   16      1000    15.6    No
# 1    New   MSI  Crosshair  Intel Core i7   32      1000    17.3    No
# 2    New  Asus   VivoBook  Intel Core i7    8       512    15.6    No
# 3    New    HP     Victus  Intel Core i7   16       512    16.1    No
# 4    New   MSI       Thin  Intel Core i7   16      1000    15.6    No
#
#    Final Price
# 0      1199.00
# 1      1699.00
# 2       809.01
# 3      1149.00
# 4      1399.00

# %%
df['Status'].value_counts()
# Out:
# Status
# New            1299
# Refurbished     627
# Name: count, dtype: int64

# %%
df['Touch'].value_counts()
# Out:
# Touch
# No     1734
# Yes     192
# Name: count, dtype: int64

# %%
df['Status']=df['Status'].replace({"New":1,"Refurbished":0})
df['Touch']=df['Touch'].replace({"Yes":1,"No":0})
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_18612\1628360684.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Status']=df['Status'].replace({"New":1,"Refurbished":0})
# C:\Users\Yash\AppData\Local\Temp\ipykernel_18612\1628360684.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Status']=df['Status'].replace({"New":1,"Refurbished":0})
# ...

# %%
df.shape
# Out:
# (1926, 9)

# %%
df.head(2)
# Out:
#    Status Brand      Model            CPU  RAM  SSD Size  Screen  Touch  \
# 0       1   MSI     Katana  Intel Core i7   16      1000    15.6      0
# 1       1   MSI  Crosshair  Intel Core i7   32      1000    17.3      0
#
#    Final Price
# 0       1199.0
# 1       1699.0

# %%
df.dtypes
# Out:
# Status           int64
# Brand           object
# Model           object
# CPU             object
# RAM              int64
# SSD Size         int64
# Screen         float64
# Touch            int64
# Final Price    float64
# dtype: object

# %%
df['Model'].value_counts()
# Out:
# Model
# 15S         110
# ROG          99
# IdeaPad      97
# ThinkPad     97
# VivoBook     94
#            ...
# V330          1
# Spectre       1
# 14w           1
# A7            1
# Delta         1
# Name: count, Length: 96, dtype: int64

# %%
model_counts=df['Model'].value_counts().reset_index()

# %%
model_counts.columns=['Model','model_count']

# %%
type(model_counts)
# Out:
# pandas.core.frame.DataFrame

# %%
df=df.merge(model_counts)

# %%
df.sample()
# Out:
#      Status Brand    Model            CPU  RAM  SSD Size  Screen  Touch  \
# 155       1   MSI  Creator  Intel Core i7   32      1000    16.0      0
#
#      Final Price  model_count
# 155      1699.01           42

# %%
df.shape
# Out:
# (1926, 10)

# %%
df=df[df['model_count']>=10]

# %%
df.shape
# Out:
# (1791, 10)

# %%
df.drop(columns=['model_count'],inplace=True)

# %%
df.columns
# Out:
# Index(['Status', 'Brand', 'Model', 'CPU', 'RAM', 'SSD Size', 'Screen', 'Touch',
#        'Final Price'],
#       dtype='object')

# %%
df['Model'].value_counts()
# Out:
# Model
# 15S               110
# ROG                99
# ThinkPad           97
# IdeaPad            97
# VivoBook           94
# TUF                58
# MacBook Pro        57
# V15                56
# ZenBook            43
# ThinkBook          43
# Latitude           43
# ExpertBook         43
# Creator            42
# Modern             40
# Surface Laptop     39
# Aspire             39
# MacBook Air        38
# Prestige           38
# EliteBook          36
# Blade              35
# Raider             34
# Stealth            34
# 250                34
# Victus             32
# Omen               31
# Vostro             30
# Surface Pro        27
# ProBook            27
# Gram               27
# Legion             26
# Katana             26
# Pavilion           24
# Aorus              23
# Extensa            23
# Zbook              21
# Yoga               21
# Pulse              21
# F515               20
# Nitro              20
# Aero               19
# Akoya              19
# ...

# %%
df.dtypes
# Out:
# Status           int64
# Brand           object
# Model           object
# CPU             object
# RAM              int64
# SSD Size         int64
# Screen         float64
# Touch            int64
# Final Price    float64
# dtype: object

# %%
df['Brand']=df['Brand'].astype('category')

# %%
df.dtypes
# Out:
# Status            int64
# Brand          category
# Model            object
# CPU              object
# RAM               int64
# SSD Size          int64
# Screen          float64
# Touch             int64
# Final Price     float64
# dtype: object

# %%
new_df=df ##assigning value of cleaned df to new_df

# %%
new_df.to_csv("Datasets/laptops_cleaned.csv")

# %%
new_df.shape
# Out:
# (1791, 9)

# %%
new_df.columns
# Out:
# Index(['Status', 'Brand', 'Model', 'CPU', 'RAM', 'SSD Size', 'Screen', 'Touch',
#        'Final Price'],
#       dtype='object')

# %%
## independent and dependent feature
X=new_df.drop(columns=['Final Price'])
y=new_df['Final Price']

# %%
print(type(X))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
print(X.shape)
print(y.shape)
# Out:
# (1791, 8)
# (1791,)

# %%
## train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train
# Out:
#       Status      Brand           Model                CPU  RAM  SSD Size  \
# 800        1        MSI          Modern      Intel Core i5    8       512
# 889        0       Acer          Aspire      Intel Core i5    8       512
# 210        1         HP             250      Intel Core i7   16       512
# 1510       1       Acer         Extensa        AMD Ryzen 5    8       512
# 521        0     Lenovo          Legion      Intel Core i7   16       512
# ...      ...        ...             ...                ...  ...       ...
# 1677       1  Microsoft  Surface Laptop  Intel Evo Core i7   16       512
# 1732       1         HP             15S      Intel Celeron    8       256
# 520        0     Lenovo          Legion      Intel Core i7   16       256
# 555        0        MSI            Thin      Intel Core i7   16       512
# 1269       1     Lenovo        ThinkPad        AMD Ryzen 7   16       512
#
#       Screen  Touch
# 800     14.0      0
# 889     17.3      0
# ...

# %%
y_train
# Out:
# 800      799.00
# 889      713.28
# 210     1057.00
# 1510     491.13
# 521      860.79
#          ...
# 1677    2079.00
# 1732     323.45
# 520      875.54
# 555      806.28
# 1269    2068.00
# Name: Final Price, Length: 1432, dtype: float64

# %%
X_train['Brand'].unique()
# Out:
# ['MSI', 'Acer', 'HP', 'Lenovo', 'Razer', ..., 'Apple', 'LG', 'Dell', 'Gigabyte', 'Medion']
# Length: 12
# Categories (12, object): ['Acer', 'Apple', 'Asus', 'Dell', ..., 'MSI', 'Medion', 'Microsoft', 'Razer']

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1432 entries, 800 to 1269
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Status    1432 non-null   int64
#  1   Brand     1432 non-null   category
#  2   Model     1432 non-null   object
#  3   CPU       1432 non-null   object
#  4   RAM       1432 non-null   int64
#  5   SSD Size  1432 non-null   int64
#  6   Screen    1432 non-null   float64
#  7   Touch     1432 non-null   int64
# dtypes: category(1), float64(1), int64(4), object(2)
# memory usage: 91.3+ KB

# %%
# label encoding on Brand,Model and CPU features of X_train
from sklearn.preprocessing import LabelEncoder
brand_le=LabelEncoder()
model_le=LabelEncoder()
cpu_le=LabelEncoder()
X_train['Brand']=brand_le.fit_transform(X_train['Brand'])
X_train['Model']=model_le.fit_transform(X_train['Model'])
X_train['CPU']=cpu_le.fit_transform(X_train['CPU'])

# %%
X_train['Brand'].unique()
# Out:
# array([ 8,  0,  5,  7, 11,  2, 10,  1,  6,  3,  4,  9])

# %%
X_train['Brand'].value_counts()
# Out:
# Brand
# 2     295
# 5     264
# 7     261
# 8     231
# 0      93
# 1      81
# 3      62
# 10     53
# 11     28
# 4      28
# 6      21
# 9      15
# Name: count, dtype: int64

# %%
X_train['Model'].unique()
# Out:
# array([23,  6,  1, 13, 19,  7, 40,  0, 24, 37, 36, 28, 20, 38, 16, 11, 27,
#        41, 29, 25, 12, 43, 31, 46, 21, 15, 10, 32, 44, 42, 47, 35, 17, 18,
#        33, 14, 22, 34,  5, 26,  3,  8, 39, 45,  4,  2,  9, 30])

# %%
X_train['Model'].value_counts()
# Out:
# Model
# 0     86
# 43    80
# 40    77
# 16    73
# 31    73
# 22    49
# 37    46
# 41    39
# 18    36
# 12    35
# 47    35
# 10    34
# 23    33
# 6     33
# 39    32
# 21    32
# 35    31
# 32    31
# 1     30
# 11    29
# 33    29
# 7     28
# 28    27
# 25    27
# 44    26
# 42    25
# 19    22
# 36    22
# 17    21
# 15    21
# 29    20
# 14    19
# 30    19
# 26    18
# 13    18
# 45    16
# 2     15
# 5     15
# 4     15
# 27    15
# 24    14
# 34    14
# 46    13
# 8     13
# 3     13
# 20    12
# 38    11
# 9     10
# Name: count, dtype: int64

# %%
X_train['CPU'].unique()
# Out:
# array([ 9, 10,  2, 12,  0,  8,  3,  4,  5, 13, 11,  7,  1,  6])

# %%
X_train['CPU'].value_counts()
# Out:
# CPU
# 10    500
# 9     374
# 3     115
# 2      94
# 8      80
# 11     70
# 13     50
# 4      30
# 1      30
# 7      28
# 5      22
# 12     21
# 0      10
# 6       8
# Name: count, dtype: int64

# %%
X_train.dtypes
# Out:
# Status        int64
# Brand         int64
# Model         int64
# CPU           int64
# RAM           int64
# SSD Size      int64
# Screen      float64
# Touch         int64
# dtype: object

# %%
X_train
# Out:
#       Status  Brand  Model  CPU  RAM  SSD Size  Screen  Touch
# 800        1      8     23    9    8       512    14.0      0
# 889        0      0      6    9    8       512    17.3      0
# 210        1      5      1   10   16       512    15.6      0
# 1510       1      0     13    2    8       512    15.6      0
# 521        0      7     19   10   16       512    15.6      0
# ...      ...    ...    ...  ...  ...       ...     ...    ...
# 1677       1     10     35   13   16       512    15.0      1
# 1732       1      5      0    7    8       256    15.6      0
# 520        0      7     19   10   16       256    15.6      0
# 555        0      8     38   10   16       512    15.6      0
# 1269       1      7     40    3   16       512    13.3      0
#
# [1432 rows x 8 columns]

# %%
## Applying OneHotEncoding and Standard Scalling -->
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

standard_scaler=StandardScaler()
X_train=standard_scaler.fit_transform(X_train)

# %%
X_train.shape
# Out:
# (1432, 8)

# %%
X_train
# Out:
# array([[ 0.70451596,  1.04833825, -0.10399664, ..., -0.28974046,
#         -1.10638646, -0.32917948],
#        [-1.41941426, -1.68550264, -1.29875557, ..., -0.28974046,
#          1.85400076, -0.32917948],
#        [ 0.70451596,  0.02314792, -1.65015525, ..., -0.28974046,
#          0.32895279, -0.32917948],
#        ...,
#        [-1.41941426,  0.70660814, -0.38511639, ..., -1.05580611,
#          0.32895279, -0.32917948],
#        [-1.41941426,  1.04833825,  0.95020242, ..., -0.28974046,
#          0.32895279, -0.32917948],
#        [ 0.70451596,  0.70660814,  1.09076229, ..., -0.28974046,
#         -1.73434739, -0.32917948]])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
## importing all possible algorithms
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
X_test
# Out:
#       Status      Brand           Model                CPU  RAM  SSD Size  \
# 98         1         HP             15S      Intel Core i7   16       512
# 988        1         HP             15S      Intel Core i5    8       512
# 592        0        MSI          Modern      Intel Core i7   16      1000
# 694        1         HP         ProBook      Intel Core i5    8       256
# 1271       1     Lenovo             V15        AMD Ryzen 7    8       512
# ...      ...        ...             ...                ...  ...       ...
# 1827       0       Asus             ROG        AMD Ryzen 9   32      1000
# 1132       0     Lenovo         IdeaPad      Intel Core i5    8       512
# 189        1        MSI          Katana      Intel Core i7   16      1000
# 894        1       Acer          Aspire      Intel Core i5    8       512
# 1679       1  Microsoft  Surface Laptop  Intel Evo Core i7    8       512
#
#       Screen  Touch
# 98      15.6      0
# 988     15.6      0
# ...

# %%
# Performing label encoding on X_test
X_test['Brand']=brand_le.transform(X_test['Brand'])
X_test['Model']=model_le.transform(X_test['Model'])
X_test['CPU']=cpu_le.transform(X_test['CPU'])

# %%
X_test
# Out:
#       Status  Brand  Model  CPU  RAM  SSD Size  Screen  Touch
# 98         1      5      0   10   16       512    15.6      0
# 988        1      5      0    9    8       512    15.6      0
# 592        0      8     23   10   16      1000    14.0      0
# 694        1      5     29    9    8       256    15.6      0
# 1271       1      7     41    3    8       512    15.6      0
# ...      ...    ...    ...  ...  ...       ...     ...    ...
# 1827       0      2     31    4   32      1000    17.3      0
# 1132       0      7     16    9    8       512    14.0      0
# 189        1      8     17   10   16      1000    15.6      0
# 894        1      0      6    9    8       512    14.0      0
# 1679       1     10     35   13    8       512    15.0      1
#
# [359 rows x 8 columns]

# %%
# Performing Standard Scaling on X_test
X_test=standard_scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.70451596,  0.02314792, -1.72043519, ..., -0.28974046,
#          0.32895279, -0.32917948],
#        [ 0.70451596,  0.02314792, -1.72043519, ..., -0.28974046,
#          0.32895279, -0.32917948],
#        [-1.41941426,  1.04833825, -0.10399664, ...,  1.17057218,
#         -1.10638646, -0.32917948],
#        ...,
#        [ 0.70451596,  1.04833825, -0.52567626, ...,  1.17057218,
#          0.32895279, -0.32917948],
#        [ 0.70451596, -1.68550264, -1.29875557, ..., -0.28974046,
#         -1.10638646, -0.32917948],
#        [ 0.70451596,  1.73179848,  0.7393626 , ..., -0.28974046,
#         -0.20929943,  3.03785639]])

# %%
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
# Creating a function to evaluate the model
def evaluate_model(true, predicted):
    R2_score=r2_score(true, predicted)
    mae=mean_absolute_error(true, predicted)
    mse=mean_squared_error(true, predicted)
    rmse=np.sqrt(mse)
    
    print("R2 Score:{:.2f}".format(R2_score))
    print("MAE:{:.2f}".format(mae))
    print("MSE:{:.2f}".format(mse))
    print("RMSE:{:.2f}".format(rmse))

# %%
## Model Training
models={
    "Linear Regression":LinearRegression(),
    "Lasso":Lasso(),
    "Ridge":Ridge(),
    "Decision Tree Regressor":DecisionTreeRegressor(),
    "K Neighbors Regressor":KNeighborsRegressor(),
    "Random Forest Regressor":RandomForestRegressor(),
    "Gradient Boosting Regressor":GradientBoostingRegressor(),
    "Ada Boost Regressor":AdaBoostRegressor(),
    "Support Vector Regressor":SVR(),
    "XGB Regressor": XGBRegressor()
}

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)
    
    y_train_pred=model.predict(X_train)
    y_test_pred=model.predict(X_test)
    
    print(list(models.keys())[i],"============>")
    print("Evaluating Train Dataset")
    evaluate_model(y_train,y_train_pred)
    print()
    print("Evaluating Test Dataset")
    evaluate_model(y_test,y_test_pred)
    print()
    print(f"\n{"-"*50}\n")
# Out:
# Linear Regression ============>
# Evaluating Train Dataset
# R2 Score:0.62
# MAE:393.82
# MSE:304382.20
# RMSE:551.71
#
# Evaluating Test Dataset
# R2 Score:0.59
# MAE:403.73
# MSE:335133.88
# RMSE:578.91
#
#
# --------------------------------------------------
#
# Lasso ============>
# Evaluating Train Dataset
# R2 Score:0.62
# MAE:393.86
# MSE:304388.63
# RMSE:551.71
#
# Evaluating Test Dataset
# R2 Score:0.59
# MAE:403.67
# MSE:334692.46
# RMSE:578.53
#
#
# --------------------------------------------------
#
# Ridge ============>
# Evaluating Train Dataset
# R2 Score:0.62
# MAE:393.82
# MSE:304382.31
# RMSE:551.71
#
# Evaluating Test Dataset
# R2 Score:0.59
# MAE:403.75
# MSE:335104.35
# RMSE:578.88
#
#
# --------------------------------------------------
#
# Decision Tree Regressor ============>
# Evaluating Train Dataset
# R2 Score:0.94
# MAE:113.42
# MSE:50633.90
# RMSE:225.02
#
# Evaluating Test Dataset
# R2 Score:0.77
# MAE:282.58
# MSE:192165.36
# RMSE:438.37
#
#
# ...

# %% [markdown]
# ## We are getting highest accuracy with
# ### XGB Regressor ============>
# - Evaluating Train Dataset
# - R2 Score:0.93
# - MAE:141.30
# - MSE:56537.23
# - RMSE:237.78
# ---------------------------
# - Evaluating Test Dataset
# - R2 Score:0.82
# - MAE:246.31
# - MSE:151515.73
# - RMSE:389.25

# %%
XGB_Regressor=XGBRegressor()
XGB_Regressor.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=XGB_Regressor.predict(X_test)

# %%
evaluate_model(y_test,y_pred)
# Out:
# R2 Score:0.82
# MAE:246.31
# MSE:151515.73
# RMSE:389.25

# %%
# Pickling the model
import pickle

# %%
brand_le
# Out:
# LabelEncoder()

# %%
model_le
# Out:
# LabelEncoder()

# %%
cpu_le
# Out:
# LabelEncoder()

# %%
standard_scaler
# Out:
# StandardScaler()

# %%
pickle.dump(brand_le,open('models/brand_le.pkl','wb'))
pickle.dump(model_le,open('models/model_le.pkl','wb'))
pickle.dump(cpu_le,open('models/cpu_le.pkl','wb'))
pickle.dump(standard_scaler,open('models/standard_scaler.pkl','wb'))
pickle.dump(XGB_Regressor,open('models/XGB_Regressor.pkl','wb'))

# %%
new_df
# Out:
#       Status   Brand     Model            CPU  RAM  SSD Size  Screen  Touch  \
# 0          1     MSI    Katana  Intel Core i7   16      1000    15.6      0
# 2          1    Asus  VivoBook  Intel Core i7    8       512    15.6      0
# 3          1      HP    Victus  Intel Core i7   16       512    16.1      0
# 4          1     MSI      Thin  Intel Core i7   16      1000    15.6      0
# 5          1    Asus  VivoBook  Intel Core i7    8       512    15.6      0
# ...      ...     ...       ...            ...  ...       ...     ...    ...
# 1921       1      HP       15S      AMD 3020e    4       256    15.6      0
# 1922       1      HP       15S      AMD 3020e    4       128    15.6      0
# 1923       1  Lenovo   IdeaPad      AMD 3020e    4       256    14.0      0
# 1924       0  Lenovo   IdeaPad      AMD 3020e    8       256    15.6      0
# 1925       0  Lenovo       V15      AMD 3020e    8       256    15.6      0
#
#       Final Price
# 0         1199.00
# ...

# %%
# pickling new_df
pickle.dump(new_df,open('models/new_df.pkl','wb'))

# %%
new_df.columns
# Out:
# Index(['Status', 'Brand', 'Model', 'CPU', 'RAM', 'SSD Size', 'Screen', 'Touch',
#        'Final Price'],
#       dtype='object')

# %%
new_df['RAM'].unique()
# Out:
# array([16,  8, 32, 12,  4, 64])

# %%
new_df['SSD Size'].unique()
# Out:
# array([1000,  512, 2000,  256,  128,  500,  240, 3000,   32,   64, 4000])

# %%
ssd_sizes=new_df['SSD Size'].unique()

# %%
type(ssd_sizes)
# Out:
# numpy.ndarray

# %%
ssd_sizes.sort()

# %%
ssd_sizes
# Out:
# array([  32,   64,  128,  240,  256,  500,  512, 1000, 2000, 3000, 4000])

# %%
new_df['Screen'].unique()
# Out:
# array([15.6, 16.1, 13.3, 16. , 14. , 17.3, 17. , 14.4, 15.4, 13.4, 12.3,
#        15. , 13. , 12.4, 12.5, 13.5, 13.9, 18. , 14.5, 11.6, 13.6, 15.3,
#        16.2, 14.2])

# %%
screen_sizes=new_df['Screen'].unique()

# %%
screen_sizes.sort()

# %%
screen_sizes
# Out:
# array([11.6, 12.3, 12.4, 12.5, 13. , 13.3, 13.4, 13.5, 13.6, 13.9, 14. ,
#        14.2, 14.4, 14.5, 15. , 15.3, 15.4, 15.6, 16. , 16.1, 16.2, 17. ,
#        17.3, 18. ])
